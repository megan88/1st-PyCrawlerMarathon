# %%
#這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import requests
import json

r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
data = json.loads(r.text)

data
# Out:
# [{'id': 232960073,
#   'title': '我家有隻顏值爆表狸花貓',
#   'excerpt': '睡覺是天使，本來以為是豹貓但是花紋是條紋的🤪，目前五個月，都會帶他出去玩，昨天帶他去爬了貓生的第一座山，正式成為山貓了️️️，直接被他萌翻，每次帶他出門路人都覺得很新奇，因為在台灣帶貓出門的主人實在',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-01-26T06:57:58.653Z',
#   'updatedAt': '2020-01-26T06:57:58.653Z',
#   'commentCount': 12,
#   'likeCount': 320,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['顏值', '貓', '寵物', '領養代替購買', '認養'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '國立臺南護理專科學校',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '9330b466-299e-4582-ba9e-7c2d20a6e2e8',
#     'url': 'https://megapx-assets.dcard.tw/images/d6623480-fd52-4d1b-a765-944b092b0db6/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/d6623480-fd52-4d1b-a765-944b092b0db6',
# ...

# %%
#取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
import requests
import json

r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
data = json.loads(r.text)

for d in data:
    print('標題:'+ str(d['title']) , end=', ')
    print('貼文時間:'+str(d['createdAt']), end=', ')
    print('留言人數:'+str(d['commentCount']), end=', ')
    print('按讚人數:'+str(d['likeCount']))
# Out:
# 標題:我家有隻顏值爆表狸花貓, 貼文時間:2020-01-26T06:57:58.653Z, 留言人數:12, 按讚人數:341
# 標題:貓貓中毒之貓奴才的養成計畫, 貼文時間:2020-01-26T07:29:12.132Z, 留言人數:14, 按讚人數:241
# 標題:加菲貓嗎..., 貼文時間:2020-01-26T08:39:08.428Z, 留言人數:3, 按讚人數:221
# 標題:史上最萌的手機支架, 貼文時間:2020-01-27T06:04:27.328Z, 留言人數:3, 按讚人數:220
# 標題:阿嬤餵狗狗吃肉的速度, 貼文時間:2020-01-26T07:10:20.857Z, 留言人數:3, 按讚人數:164
# 標題:貓睡前怪癖, 貼文時間:2020-01-26T16:35:01.636Z, 留言人數:9, 按讚人數:141
# 標題:我的貓到底為什麼這麼ㄎㄧㄤ, 貼文時間:2020-01-26T03:57:37.668Z, 留言人數:14, 按讚人數:95
# 標題:#更 有人想養小貓嗎, 貼文時間:2020-01-26T15:09:16.527Z, 留言人數:17, 按讚人數:87
# 標題:關於繞貓三圈的傳說, 貼文時間:2020-01-26T16:01:21.464Z, 留言人數:7, 按讚人數:84
# 標題:帶我走好嗎？, 貼文時間:2020-01-26T12:07:14.090Z, 留言人數:3, 按讚人數:80
# 標題:我還以為你死了, 貼文時間:2020-01-26T07:17:41.405Z, 留言人數:6, 按讚人數:60
# 標題:龜哥, 貼文時間:2020-01-26T03:03:23.540Z, 留言人數:8, 按讚人數:48
# 標題:脆雞來拜年🌸, 貼文時間:2020-01-26T10:01:56.867Z, 留言人數:7, 按讚人數:42
# 標題:我就是要曬狗而已, 貼文時間:2020-01-27T04:51:18.618Z, 留言人數:5, 按讚人數:39
# 標題:好運龜龜豆皮🐢🧨, 貼文時間:2020-01-26T13:44:14.885Z, 留言人數:6, 按讚人數:35
# ...

# %%
#計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
import requests
import json

#計算熱門文章的「平均留言人數」
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
data = json.loads(r.text)

commentCount = 0 #留言人數
likeCount = 0 #按讚人數
count = 0 #筆數

for d in data:
    commentCount=commentCount+d['commentCount']
    likeCount=likeCount+d['likeCount']
    count=count+1

print('熱門文章的「平均留言人數」:'+str(commentCount/count), end=', ')
print('「平均按讚人數」:'+str(likeCount/count))

#計算非熱門文章的「平均留言人數」
r2 = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
data2 = json.loads(r2.text)

commentCount2 = 0 #留言人數
likeCount2 = 0 #按讚人數
count2 = 0 #筆數
avgcommentCount2=0  #平均留言人數

for d2 in data2:
    commentCount2=commentCount2+d['commentCount']
    likeCount2=likeCount2+d['likeCount']
    count2=count2+1
    
    
print('非熱門文章的「平均留言人數」:'+str(commentCount2/count2), end=', ')
print('「平均按讚人數」:'+str(likeCount2/count2))
# Out:
# 熱門文章的「平均留言人數」:5.333333333333333, 「平均按讚人數」:74.6
# 非熱門文章的「平均留言人數」:8.0, 「平均按讚人數」:4.0
