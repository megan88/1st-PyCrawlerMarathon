# %%
#下載網頁內容並比較「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
import requests
import json

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11364314768","type":"PullRequestEvent","actor":{"id":27856297,"login":"dependabot-preview[bot]","display_login":"dependabot-preview","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview[bot]","avatar_url":"https://avatars.githubusercontent.com/u/27856297?"},"repo":{"id":197922969,"name":"Rexogamer/cytrus-re","url":"https://api.github.com/repos/Rexogamer/cytrus-re"},"payload":{"action":"opened","number":162,"pull_request":{"url":"https://api.github.com/repos/Rexogamer/cytrus-re/pulls/162","id":367357268,"node_id":"MDExOlB1bGxSZXF1ZXN0MzY3MzU3MjY4","html_url":"https://github.com/Rexogamer/cytrus-re/pull/162","diff_url":"https://github.com/Rexogamer/cytrus-re/pull/162.diff","patch_url":"https://github.com/Rexogamer/cytrus-re/pull/162.patch","issue_url":"https://api.github.com/repos/Rexogamer/cytrus-re/issues/162","number":162,"state":"open","locked":false,"title":"Bump discord.js from `63293fe` to `030d263`","user":{"login":"dependabot-preview[bot]","id":2785
# ...

# %%
import requests
import json

r = requests.get('https://api.github.com/events')
json.loads(r.text)
# Out:
# [{'id': '11364315707',
#   'type': 'DeleteEvent',
#   'actor': {'id': 823661,
#    'login': 'Macroz',
#    'display_login': 'Macroz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Macroz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/823661?'},
#   'repo': {'id': 73476171,
#    'name': 'CSCfi/rems',
#    'url': 'https://api.github.com/repos/CSCfi/rems'},
#   'payload': {'ref': 'refactor-field-id',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-01-27T07:56:10Z',
#   'org': {'id': 5947494,
#    'login': 'CSCfi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CSCfi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5947494?'}},
#  {'id': '11364315702',
#   'type': 'PushEvent',
#   'actor': {'id': 19306090,
#    'login': 'suryanshusingh',
#    'display_login': 'suryanshusingh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/suryanshusingh',
# ...

# %%
#自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
import requests

r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel',data = {'key':'value'})
json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2200H029',
#    'WaterLevel': 145.15},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': 226.25},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': 1.28},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.73},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2560H019',
#    'WaterLevel': 4.48},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1580H001',
#    'WaterLevel': 224.21},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': 92.83},
#   {'RecordTime': 'Dec 11, 2019 2:50:00 PM',
#    'StationIdentifier': '2420H036',
# ...
